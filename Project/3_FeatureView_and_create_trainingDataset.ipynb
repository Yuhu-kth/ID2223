# %%
# !pip install -U hopsworks --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 KB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 KB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 KB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 KB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.2/68.2 KB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 5.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 39.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 KB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 41.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 82.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 17.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 102.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 KB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 KB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 95.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 90.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 KB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 KB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.3/555.3 KB 47.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.0 MB/s eta 0:00:00
#   Building wheel for hopsworks (setup.py) ... done
#   Building wheel for avro (setup.py) ... done
#   Building wheel for hsml (setup.py) ... done
#   Building wheel for hsfs (setup.py) ... done
#   Building wheel for twofish (setup.py) ... done
#   Building wheel for thrift (setup.py) ... done
#   Building wheel for pyhopshive (setup.py) ... done

# %%
#Connect to Hopsworks
import hopsworks
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/7374
# Connected. Call `.close()` to terminate connection gracefully.

# %%
air_quality_fg = fs.get_or_create_feature_group(
    name = 'air_quality_fg',
    version = 3
)
weather_fg = fs.get_or_create_feature_group(
    name = 'weather_fg',
    version = 1
)

# %%
query = air_quality_fg.select_all().join(weather_fg.select_all())
query.read()

query = air_quality_fg.select_all().join(weather_fg.select_all())
query_show = query.show(5)
print(query_show)

col_names = query_show.columns
print(col_names)
# Out:
#             date   pm25   pm10    o3     city  tempmax  tempmin  temp  \
# 0  1673996400000  138.0   58.0   1.0  Beijing      0.5    -13.0  -4.3
# 1  1673650800000   12.0    0.0   0.0  Beijing     -2.0     -7.0  -4.5
# 2  1673564400000  145.0   11.0  26.0  Beijing      6.3     -1.8   2.2
# 3  1673478000000  170.0   68.0  25.0  Beijing      3.3      1.0   1.7
# 4  1673391600000  159.0  117.0   2.0  Beijing      3.0     -8.0  -1.8
#
#    feelslikemax  feelslikemin  ...  snowdepth  windgust  windspeed  winddir  \
# 0          -0.6         -15.3  ...        0.0      25.9        7.6    233.4
# 1          -6.7         -14.1  ...        0.0      57.6       28.8    331.1
# 2           4.4          -8.0  ...        0.0      50.4       25.2    353.2
# 3           3.3          -3.1  ...        0.0      16.2       14.4    341.2
# 4           3.0          -8.0  ...        0.0      25.2        7.2     26.6
#
#    sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0            1024.9         0.0        19.4           120.5         10.4
# 1            1034.8        68.8        13.2            90.5          7.9
# 2            1019.6        78.3         7.0            63.2          5.4
# 3            1016.2        58.2         7.5            40.1          3.4
# 4            1021.9        66.6         9.7            88.3          7.6
#
#                      conditions
# 0                         Clear
# 1              Partially cloudy
# 2              Partially cloudy
# 3  Snow, Rain, Partially cloudy
# 4              Partially cloudy
#
# [5 rows x 26 columns]
# Index(['date', 'pm25', 'pm10', 'o3', 'city', 'tempmax', 'tempmin', 'temp',
#        'feelslikemax', 'feelslikemin', 'feelslike', 'dew', 'humidity',
#        'precip', 'precipcover', 'snow', 'snowdepth', 'windgust', 'windspeed',
#        'winddir', 'sealevelpressure', 'cloudcover', 'visibility',
#        'solarradiation', 'solarenergy', 'conditions'],
#       dtype='object')

# %%
query.show(20)
# Out:
#              date   pm25   pm10    o3     city  tempmax  tempmin  temp  \
# 0   1673996400000  138.0   58.0   1.0  Beijing      0.5    -13.0  -4.3
# 1   1673650800000   12.0    0.0   0.0  Beijing     -2.0     -7.0  -4.5
# 2   1673564400000  145.0   11.0  26.0  Beijing      6.3     -1.8   2.2
# 3   1673478000000  170.0   68.0  25.0  Beijing      3.3      1.0   1.7
# 4   1673391600000  159.0  117.0   2.0  Beijing      3.0     -8.0  -1.8
# 5   1673305200000  121.0   82.0   2.0  Beijing      6.0     -7.0  -1.4
# 6   1673218800000   52.0   62.0  13.0  Beijing      9.0     -3.0   3.3
# 7   1673132400000   79.0   35.0  21.0  Beijing     11.5     -7.0   2.3
# 8   1673046000000   71.0   59.0  21.0  Beijing      8.0    -10.0  -2.2
# 9   1672959600000  124.0   67.0   8.0  Beijing      9.0     -7.0  -0.2
# 10  1672873200000  170.0   88.0  26.0  Beijing      5.0    -12.0  -4.6
# 11  1672786800000  111.0   93.0   7.0  Beijing      5.0    -11.0  -4.3
# 12  1672700400000   59.0   62.0  12.0  Beijing      2.5    -10.0  -4.9
# 13  1672614000000   37.0   38.0  16.0  Beijing      3.0     -9.0  -2.7
# 14  1672527600000   62.0   16.0  21.0  Beijing      5.0    -12.0  -4.0
# 15  1672441200000   77.0   34.0  19.0  Beijing      7.0    -12.0  -4.3
# 16  1672354800000   70.0   52.0  17.0  Beijing      4.0    -13.0  -5.6
# 17  1672268400000   41.0   39.0  13.0  Beijing      2.3    -10.0  -3.9
# 18  1672182000000   61.0   21.0  24.0  Beijing      3.0    -14.0  -4.9
# 19  1672095600000   46.0   36.0  17.0  Beijing      0.0    -12.0  -4.3
#
#     feelslikemax  feelslikemin  ...  snowdepth  windgust  windspeed  winddir  \
# 0           -0.6         -15.3  ...        0.0      25.9        7.6    233.4
# 1           -6.7         -14.1  ...        0.0      57.6       28.8    331.1
# 2            4.4          -8.0  ...        0.0      50.4       25.2    353.2
# 3            3.3          -3.1  ...        0.0      16.2       14.4    341.2
# 4            3.0          -8.0  ...        0.0      25.2        7.2     26.6
# 5            4.6          -7.7  ...        0.0      25.2       10.8    166.3
# 6            9.0          -3.6  ...        0.0      28.8       18.0    152.0
# 7           11.5         -10.6  ...        0.0      31.3       18.0     22.8
# 8            8.0         -11.8  ...        0.0      43.2       10.8      3.1
# 9            5.7         -11.7  ...        0.0      57.6       39.6    320.9
# 10           5.0         -16.4  ...        0.0      14.4       10.8    345.6
# 11           5.0         -14.1  ...        0.0      14.4       10.8    250.2
# 12           2.0         -15.5  ...        0.0      18.0       14.4    343.5
# 13           3.0         -12.9  ...        0.0      25.2       18.0     24.5
# 14           5.0         -16.4  ...        0.0      18.0       14.4      1.5
# 15           5.6         -16.4  ...        0.0      37.1       14.4    353.3
# 16           3.0         -17.6  ...        0.0      21.6       10.8    299.5
# 17          -0.8         -12.9  ...        0.0      37.8       21.6    331.6
# 18          -0.3         -18.8  ...        0.0      43.2       32.4    297.0
# 19          -4.7         -17.9  ...        0.0      51.8       32.4    307.1
#
#     sealevelpressure  cloudcover  visibility  solarradiation  solarenergy  \
# 0             1024.9         0.0        19.4           120.5         10.4
# 1             1034.8        68.8        13.2            90.5          7.9
# 2             1019.6        78.3         7.0            63.2          5.4
# 3             1016.2        58.2         7.5            40.1          3.4
# 4             1021.9        66.6         9.7            88.3          7.6
# 5             1029.0         2.9        11.3           109.0          9.4
# 6             1032.6        12.1        11.7           108.8          9.4
# 7             1022.2        41.0        11.2           108.2          9.4
# 8             1021.0        52.2        10.7            77.3          6.7
# 9             1021.5         1.3         8.4           108.0          9.4
# 10            1028.9         5.2         8.4           107.2          9.3
# 11            1030.7         2.6        10.4           105.9          9.2
# 12            1032.3        21.9        11.9            97.8          8.4
# 13            1037.2        29.2        12.6           106.4          9.1
# 14            1035.8        33.6        11.3            98.8          8.6
# 15            1030.9         1.6        11.0           105.3          9.0
# 16            1032.6         0.0        11.2           107.5          9.3
# 17            1035.0         0.1        12.7           105.5          9.0
# 18            1032.9        11.5        11.5           103.6          8.9
# 19            1032.7         0.5        12.6           104.8          9.0
#
#                       conditions
# 0                          Clear
# 1               Partially cloudy
# 2               Partially cloudy
# 3   Snow, Rain, Partially cloudy
# 4               Partially cloudy
# 5                          Clear
# 6                          Clear
# 7               Partially cloudy
# 8               Partially cloudy
# 9                          Clear
# 10                         Clear
# 11                         Clear
# 12              Partially cloudy
# 13              Partially cloudy
# 14              Partially cloudy
# 15                         Clear
# 16                         Clear
# 17                         Clear
# 18                         Clear
# 19                         Clear
#
# [20 rows x 26 columns]

# %%
#Transformation
[t_func.name for t_func in fs.get_transformation_functions()]
category_cols = ['city', 'date','conditions']
mapping_transformers = {col_name:fs.get_transformation_function(name='standard_scaler') for col_name in col_names if col_name not in category_cols}
category_cols = {col_name:fs.get_transformation_function(name='label_encoder') for col_name in category_cols if col_name not in ['date']}
mapping_transformers.update(category_cols)

# %%
#Add to hopsworks
feature_view = fs.create_feature_view(
    name = 'air_quality_fv',
    version = 1,
    transformation_functions = mapping_transformers,
    query = query
)

feature_view = fs.get_feature_view(
    name = 'air_quality_fv',
    version = 1
)
# Out:
# Feature view created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/7374/fs/7294/fv/air_quality_fv/version/1

# %%
#Create feature view
feature_view.create_training_data()
# Out:
# Training dataset job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/7374/jobs/named/air_quality_fv_1_1_create_fv_td_18012023010215/executions
# VersionWarning: Incremented version to `1`.
# (1, <hsfs.core.job.Job at 0x7fa3715b7670>)
